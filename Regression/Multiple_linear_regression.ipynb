# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("50_Startups.csv")
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# Encoding the Categorical data

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
ct = ColumnTransformer(transformers=[("encode", OneHotEncoder(), [-1])], remainder="passthrough")
X = np.array(ct.fit_transform(X))

# %% [markdown]
# Splitting the dataset into training and test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# Training the Multiple linear regression Model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predicting

# %%
y_pre = predicted = regressor.predict(X_test)
np.printoptions(precision=2)
a = np.concatenate((y_test.reshape(len(y_test), 1), predicted.reshape(len(predicted), 1)), axis=1)

# %%
a
# Out:
# array([[103282.38      , 103015.20159795],
#        [144259.4       , 132582.27760816],
#        [146121.95      , 132447.73845175],
#        [ 77798.83      ,  71976.09851258],
#        [191050.39      , 178537.48221057],
#        [105008.31      , 116161.24230167],
#        [ 81229.06      ,  67851.69209676],
#        [ 97483.56      ,  98791.73374687],
#        [110352.25      , 113969.43533014],
#        [166187.94      , 167921.06569552]])

# %%
from sklearn.metrics import r2_score
r2_score(y_pre, y_test)
# Out:
# 0.9293749209318531
