# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Position_Salaries.csv")
X = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values

# %%
y = y.reshape(len(y), 1)

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X = sc_X.fit_transform(X)

sc_y = StandardScaler()
y = sc_y.fit_transform(y)

# %% [markdown]
# Training the SVR Model

# %%
from sklearn.svm import SVR
regressor = SVR(kernel="rbf")
regressor.fit(X, y)

# %% [markdown]
# Predicting new value result

# %%
sc_y.inverse_transform(regressor.predict(sc_X.fit_transform([[6.5]])).reshape(-1, 1))
# Out:
# array([[131106.77303274]])

# %%
y_pre = sc_y.inverse_transform(regressor.predict(X).reshape(-1, 1))

# %% [markdown]
# Visualising the result

# %%
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color="red")
plt.plot(sc_X.inverse_transform(X), y_pre, color="blue")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.title("Super Vector Regression")
plt.show()
